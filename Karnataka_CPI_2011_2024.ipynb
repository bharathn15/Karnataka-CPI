# %% [markdown]
# <a href="https://colab.research.google.com/github/bharathn15/Karnataka-CPI/blob/main/Karnataka_CPI_2011_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### Numerical to numerical
from google.colab import files
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Upload the CSV file
uploaded = files.upload()

# Step 2: Read the CSV file using pandas
# The uploaded dictionary will contain the filename as the key and the file content as the value
cpi = next(iter(uploaded))
df = pd.read_csv(cpi)
# Out:
#      <input type="file" id="files-50b9040c-9d9a-47dc-9ade-a2bcf183b110" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-50b9040c-9d9a-47dc-9ade-a2bcf183b110">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
for file in uploaded.keys():
  df = pd.read_csv(file)
  print(df.head())
# Out:
#         Sector  Year      Name  Karnataka CPI  Karnataka CPI.1  Unnamed: 5  \
# 0        Rural  2011   January          104.0            104.0         NaN
# 1        Urban  2011   January          104.0            104.0         NaN
# 2  Rural+Urban  2011   January          104.0            104.0         NaN
# 3        Rural  2011  February          106.0            106.0         NaN
# 4        Urban  2011  February          108.0            108.0         NaN
#
#   Sector.1  Year.1    Name.1  Karnataka CPI.2  Karnataka CPI.3  \
# 0    Rural  2011.0   January            104.0            104.0
# 1      NaN  2011.0  February            106.0            106.0
# 2      NaN  2011.0     March            104.8            104.8
# 3      NaN  2011.0     April            106.0            106.0
# 4      NaN  2011.0       May            109.3            109.3
#
#    Average Rural Karnataka CPI  Unnamed: 12 Sector.2  Year.2    Name.2  \
# ...

# %%
df[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-78a33f69c558> in <cell line: 1>()
# ----> 1 df[1]
#
# ...
